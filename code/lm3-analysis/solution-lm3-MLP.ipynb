# %% [markdown]
# # MLP Classifier
# MLP classifier on lm3 dataset. Remember to check path of lm3.csv before executing the file

# %%
# Load original dataset
import pandas as pd

file_path = r'lm3.csv'
data_df = pd.read_csv(file_path)
print('Num of features: %s' % len(data_df.columns.values))
data_df.head()
# Out:
# Num of features: 79
#      Label  Outer left eyebrow-x  Outer left eyebrow-y  Outer left eyebrow-z  \
# 0    ANGER               -72.961                -1.725                22.958
# 1  DISGUST               -76.565                -0.458                 6.126
# 2     FEAR               -76.163                 6.390                10.784
# 3    HAPPY               -72.140                 8.896                 9.353
# 4  SADNESS               -73.743                 3.099                12.438
#
#    Middle left eyebrow-x  Middle left eyebrow-y  Middle left eyebrow-z  \
# 0                -55.678                  4.591                 38.791
# 1                -62.086                  9.454                 24.055
# 2                -57.083                 16.865                 30.162
# 3                -54.721                 22.380                 27.474
# 4                -58.607                 15.144                 29.381
#
#    Inner left eyebrow-x  Inner left eyebrow-y  Inner left eyebrow-z  \
# 0               -31.920                -1.929                36.645
# 1               -35.614                 2.066                25.073
# 2               -33.708                14.082                32.408
# 3               -29.789                15.802                28.937
# 4               -32.979                11.594                30.048
#
#          ...         Lower lip outer middle-z  Chin middle-x  Chin middle-y  \
# 0        ...                           39.421         -9.840       -112.234
# 1        ...                           24.378        -13.583       -109.568
# 2        ...                           42.100        -13.020       -110.107
# 3        ...                           38.018         -9.030        -97.687
# 4        ...                           41.452        -10.731       -100.452
#
#    Chin middle-z  Left ear lobe-x  Left ear lobe-y  Left ear lobe-z  \
# 0         31.313              NaN              NaN              NaN
# 1         19.583              NaN              NaN              NaN
# 2         33.429              NaN              NaN              NaN
# 3         36.058              NaN              NaN              NaN
# 4         35.956              NaN              NaN              NaN
#
#    Right ear lobe-x  Right ear lobe-y  Right ear lobe-z
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
# 2               NaN               NaN               NaN
# 3               NaN               NaN               NaN
# 4               NaN               NaN               NaN
#
# [5 rows x 79 columns]

# %%
from preprocess_lm3 import preprocess_data, reduce_features

column_names, principal_labels_df = reduce_features(preprocess_data(data_df))

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from constants import get_all_emotions
from splitting import get_train_test_split

runs = 100
mlp_scores = []
for index in range(runs):
    # Split train and test labels/data
    train_data,train_labels,test_data,test_labels = get_train_test_split(principal_labels_df,column_names,index)
    
    # MLP classifier to predict
    mlp = MLPClassifier(solver='adam', activation='relu', \
                        hidden_layer_sizes=(21), max_iter=200)
    mlp.fit(train_data, train_labels)
    predicted_labels = mlp.predict(test_data)
    acc_mlp = accuracy_score(test_labels, predicted_labels)
    mlp_scores.append(acc_mlp)

print('--------------------Result--------------------')
print('MLP classifier accuracy: %.02f%%' % (sum(mlp_scores) / runs))
# Out:
# --------------------Training--------------------
#           Col 1  Col 2  Col 3  Col 4  Col 5  Col 6  Col 7  Col 8  Col 9  \
# Label
# ANGER        60     60     60     60     60     60     60     60     60
# DISGUST      60     60     60     60     60     60     60     60     60
# FEAR         60     60     60     60     60     60     60     60     60
# HAPPY        60     60     60     60     60     60     60     60     60
# SADNESS      60     60     60     60     60     60     60     60     60
# SURPRISE     60     60     60     60     60     60     60     60     60
#
#           Col 10  Col 11  Col 12  Col 13
# Label
# ANGER         60      60      60      60
# DISGUST       60      60      60      60
# FEAR          60      60      60      60
# HAPPY         60      60      60      60
# SADNESS       60      60      60      60
# SURPRISE      60      60      60      60
# Total number of inputs: 360
# --------------------Testing--------------------
#           Col 1  Col 2  Col 3  Col 4  Col 5  Col 6  Col 7  Col 8  Col 9  \
# Label
# ANGER        11     11     11     11     11     11     11     11     11
# DISGUST       9      9      9      9      9      9      9      9      9
# FEAR         10     10     10     10     10     10     10     10     10
# HAPPY        46     46     46     46     46     46     46     46     46
# SADNESS       6      6      6      6      6      6      6      6      6
# SURPRISE     11     11     11     11     11     11     11     11     11
#
#           Col 10  Col 11  Col 12  Col 13
# Label
# ANGER         11      11      11      11
# DISGUST        9       9       9       9
# FEAR          10      10      10      10
# HAPPY         46      46      46      46
# SADNESS        6       6       6       6
# SURPRISE      11      11      11      11
# Total number of inputs: 93
# c:\users\ankur shukla\anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# --------------------Result--------------------
# MLP classifier accuracy: 0.59%
